# %%
# Slower but always guaranteed to work
# !wget -nc https://archive.org/download/google-news-vectors-negative-300.bin_202311/GoogleNews-vectors-negative300.bin.gz

# You are better off just downloading this from the source
# https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM/edit?usp=sharing
# https://code.google.com/archive/p/word2vec/
# Out:
# --2025-02-04 04:17:57--  https://archive.org/download/google-news-vectors-negative-300.bin_202311/GoogleNews-vectors-negative300.bin.gz
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia601203.us.archive.org/18/items/google-news-vectors-negative-300.bin_202311/GoogleNews-vectors-negative300.bin.gz [following]
# --2025-02-04 04:17:57--  https://ia601203.us.archive.org/18/items/google-news-vectors-negative-300.bin_202311/GoogleNews-vectors-negative300.bin.gz
# Resolving ia601203.us.archive.org (ia601203.us.archive.org)... 207.241.227.133
# Connecting to ia601203.us.archive.org (ia601203.us.archive.org)|207.241.227.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1647046227 (1.5G) [application/octet-stream]
# Saving to: ‘GoogleNews-vectors-negative300.bin.gz’
#
# GoogleNews-vectors- 100%[===================>]   1.53G  45.4MB/s    in 31s
#
# 2025-02-04 04:18:28 (50.9 MB/s) - ‘GoogleNews-vectors-negative300.bin.gz’ saved [1647046227/1647046227]

# %%
# !gunzip GoogleNews-vectors-negative300.bin.gz

# %%
from gensim.models import KeyedVectors

# %%
word_vectors = KeyedVectors.load_word2vec_format(
  'GoogleNews-vectors-negative300.bin',
  binary=True
)

# %%
def find_analogies(w1, w2, w3):
  # w1 - w2 = ? - w3
  # e.g. king - man = ? - woman
  #      ? = +king +woman -man
  r = word_vectors.most_similar(positive=[w1, w3], negative=[w2])
  print("%s - %s = %s - %s" % (w1, w2, r[0][0], w3))

# %%
find_analogies('king', 'man', 'woman')
# Out:
# king - man = queen - woman

# %%
find_analogies('france', 'paris', 'london')
# Out:
# france - paris = england - london

# %%
find_analogies('france', 'paris', 'rome')
# Out:
# france - paris = italy - rome

# %%
find_analogies('paris', 'france', 'italy')
# Out:
# paris - france = lohan - italy

# %%
find_analogies('france', 'french', 'english')
# Out:
# france - french = england - english

# %%
find_analogies('december', 'november', 'june')
# Out:
# december - november = september - june

# %%
find_analogies('miami', 'florida', 'texas')
# Out:
# miami - florida = dallas - texas

# %%
find_analogies('einstein', 'scientist', 'painter')
# Out:
# einstein - scientist = jude - painter

# %%
find_analogies('man', 'woman', 'she')
# Out:
# man - woman = he - she

# %%
find_analogies('man', 'woman', 'aunt')
# Out:
# man - woman = uncle - aunt

# %%
def nearest_neighbors(w):
  r = word_vectors.most_similar(positive=[w])
  print("neighbors of: %s" % w)
  for word, score in r:
    print("\t%s" % word)

# %%
nearest_neighbors('king')
# Out:
# neighbors of: king
# 	kings
# 	queen
# 	monarch
# 	crown_prince
# 	prince
# 	sultan
# 	ruler
# 	princes
# 	Prince_Paras
# 	throne

# %%
nearest_neighbors('france')
# Out:
# neighbors of: france
# 	spain
# 	french
# 	germany
# 	europe
# 	italy
# 	england
# 	european
# 	belgium
# 	usa
# 	serbia

# %%
nearest_neighbors('japan')
# Out:
# neighbors of: japan
# 	japanese
# 	tokyo
# 	america
# 	europe
# 	germany
# 	chinese
# 	india
# 	hawaii
# 	usa
# 	korea

# %%
nearest_neighbors('nephew')
# Out:
# neighbors of: nephew
# 	son
# 	uncle
# 	brother
# 	grandson
# 	cousin
# 	father
# 	niece
# 	younger_brother
# 	nephews
# 	stepson
